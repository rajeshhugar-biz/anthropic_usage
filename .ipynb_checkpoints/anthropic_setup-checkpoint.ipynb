# %%
#Load env variables and create client
from dotenv import load_dotenv

load_dotenv()

#Create an API client
from anthropic import Anthropic

client = Anthropic()
model ="claude-sonnet-4-6"

# %%
#Helper Functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


#make a request to Claude
def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages
    )
    return message.content[0].text

# %%
#Make a starting list of messages
messages = []

#add in the initial user question of "Define quantum computing in one sentence"
add_user_message(messages, "Define quantum computing in one sentence")

#pass the list of messages into 'chat' to get an answer
answer = chat(messages)


# # #Take the answer and add it as an assistant message into our list
add_assistant_message(messages, answer)

# messages
# #add in the user's follow up question
add_user_message(messages, "Write another sentence")

# #call chat again with the list of messages to get a final answer
answer = chat(messages)

answer
#call chat again with the list of messages to get a final answer
# Out:
# 'Unlike classical computers, which store information as binary bits (0s or 1s), quantum computers use **qubits** that can exist in multiple states simultaneously, enabling them to perform many calculations at once and tackle problems in fields like cryptography, drug discovery, and optimization that would take traditional computers millions of years to solve.'

# %%
# modified chat function
#make a request to Claude
def chat(messages, system=None, temperature=1.0):
    params= {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature
    }

    if system:
        params["system"] = system
    
    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []

system="""
You are a patient math tutor.
Do Not directly answer a students's questions
Guide them to a solution step by step
"""

add_user_message(messages,"How do i solve 5x+2=2 for x?" )
answer = chat(messages, system)

answer
# Out:
# "Let's work through this together!\n\nLooking at the equation **5x + 2 = 2**, our goal is to get **x by itself**.\n\n**First step:** What do you notice about the numbers on both sides of the equation? Is there anything you could do to start simplifying it?\n\n*Hint: Think about the +2 on the left side - how might you get rid of it?* 😊"

# %%
#Helper Functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


messages = []

add_user_message(messages,"Write a 1 sentence description of a fake database")


stream = client.messages.create(
    model=model,
    max_tokens=1000,
    messages=messages,
    stream=True

)


for event in stream:
    print(event)
# Out:
# RawMessageStartEvent(message=Message(id='msg_01DoARap2hrsTWbU7pMAGqXR', container=None, content=[], model='claude-sonnet-4-6', role='assistant', stop_details=None, stop_reason=None, stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='global', input_tokens=18, output_tokens=1, output_tokens_details=None, server_tool_use=None, service_tier='standard')), type='message_start')
# RawContentBlockStartEvent(content_block=TextBlock(citations=None, text='', type='text'), index=0, type='content_block_start')
# RawContentBlockDeltaEvent(delta=TextDelta(text='Here', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=' is a one sentence description of a fake database:\n\n**FrostBase', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text='** is a fictional cloud-based database management system that stores and retrieves interdimens', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text='ional travel records for a network of time-traveling government agents', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=' across 47 parallel universes.', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockStopEvent(index=0, type='content_block_stop')
# RawMessageDeltaEvent(delta=Delta(container=None, stop_details=None, stop_reason='end_turn', stop_sequence=None), type='message_delta', usage=MessageDeltaUsage(cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=18, output_tokens=56, output_tokens_details=None, server_tool_use=None))
# RawMessageStopEvent(type='message_stop')

# %%
messages = []

add_user_message(messages,"Write a 1 sentence description of a fake database")

with client.messages.stream(
    model=model,
    max_tokens=1000,
    messages=messages

) as stream:
    for text in stream.text_stream:
        print(text,end="")



stream.get_final_message()
# Out:
# Here is a one sentence description of a fake database:
#
# **"CustomerVault Pro is a fictional cloud-based database containing the personal records, purchase histories, and behavioral data of 47 million imaginary customers from the made-up retail company, Zenith Marketplace Inc."**
# ParsedMessage(id='msg_01XFCgDR2jKEQGymXdUTnWoL', container=None, content=[ParsedTextBlock(citations=None, text='Here is a one sentence description of a fake database:\n\n**"CustomerVault Pro is a fictional cloud-based database containing the personal records, purchase histories, and behavioral data of 47 million imaginary customers from the made-up retail company, Zenith Marketplace Inc."**', type='text', parsed_output=None)], model='claude-sonnet-4-6', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='global', input_tokens=18, output_tokens=63, output_tokens_details=None, server_tool_use=None, service_tier='standard'))

# %%
messages = []

add_user_message(messages,"Generate a very short event bridge rule as a json ")

add_assistant_message(messages,"```json")

text = chat(messages,stop=["```"]
            )


text
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 7
#       3 add_user_message(messages,"Generate a very short event bridge rule as a json ")
#       4
#       5 add_assistant_message(messages,"```json")
#       6
# ----> 7 text = chat(messages,stop_sequences=["```"]
#       8             )
#       9
#      10
#
# TypeError: chat() got an unexpected keyword argument 'stop_sequences'

# %%
import json
